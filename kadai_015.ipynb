# %%
class Human:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def printinfo(self):
        print("名前:", self.name)
        print("年齢:", self.age)

human1 = Human("Yamada",43)

human1.printinfo()
# Out:
# 名前: Yamada
# 年齢: 43
